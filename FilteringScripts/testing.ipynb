# %%
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns

# from posydon.popsyn.binarypopulation import BinaryPopulation
# from posydon.binary_evol.binarystar import BinaryStar
# from posydon.binary_evol.singlestar import SingleStar
from posydon.popsyn.synthetic_population import Population
# from posydon.popsyn.synthetic_population import PopulationRunner
# import astropy.units as u

# import os
# import shutil
# from posydon.config import PATH_TO_POSYDON

from POSYDONHRDiagramModule import HR_Diagram

import matplotlib.pyplot as plt

import random as rand 

from collections import Counter

DataPath = Path().resolve().parent / 'Data'

# %%
cols = ['time', 'step_names', 'state', 
        'event', 'S1_state', 'S2_state', 
        'S1_mass', 'S2_mass', 'orbital_period']
finCols = [
    'orbital_period_f',
    'eccentricity_f',
    'state_f',

    'S1_state_f',
    'S2_state_f',
    
    'S2_mass_f',
    'S2_log_R_f',
    'S2_log_L_f',


    'S1_mass_f',
    'S1_log_R_f',
    'S1_log_L_f'

 ]

initCols = [
    'orbital_period_i',
    'eccentricity_i',
    'state_i',

    'S2_state_i',
    'S2_mass_i',
    'S2_log_R_i',

    'S1_state_i',
    'S1_mass_i',
    'S1_log_R_i'
 ]

# %%
pop = Population('/home/bku2126/b1095/bku2126/stellarBHs/grids/g2/1e+00_Zsun_population.h5')
# pop.calculate_formation_channels()
# merged = pop.oneline.select("state_f == merged")

# %%
randSamp10k_i = pop.oneline.select().sample(10000, random_state = 42).index.to_list()
pop.export_selection(randSamp10k_i, '/home/bku2126/b1095/bku2126/bns-offsets/data/10kSample.h5')

# %%
randSamp1k_i = pop.oneline.select().sample(1000, random_state = 42).index.to_list()
pop.export_selection(randSamp1k_i, '/home/bku2126/b1095/bku2126/bns-offsets/data/1kSample.h5', overwrite = True)

# %%
randSamp100_i = pop.oneline.select().sample(100, random_state = 42).index.to_list()
pop.export_selection(randSamp100_i, '/home/bku2126/b1095/bku2126/bns-offsets/data/100Sample.h5', overwrite = True)

# %%
bh_bh = pop.oneline.select("(S1_state_f == BH) & (S2_state_f == BH) & (state_f == detached)")

# %%
bhbhexport_sample = bh_bh.sample(100,random_state = 42).index.to_list()

# %%
pop.export_selection(bhbhexport_sample, '/home/bku2126/b1095/bku2126/stellarBHs/Data/bhbh100.h5')

# %%
# pop.export_selection(merged.index.to_list(), '/home/bku2126/b1095/bku2126/stellarBHs/Data/oneMillMerged.h5')

# %%
pop = Population('/home/bku2126/b1095/bku2126/stellarBHs/Data/oneMillMerged.h5')

# %%
bhSolPop = Population('/home/bku2126/b1095/bku2126/stellarBHs/Data/10MillFilt/BH_Sol_Filtered_1e+00_Zsun_population.h5')
# Out:
# Missing ini parameter: posydon_version

# %%
bhSolPop.history.select()[cols]
# Out:
#                       time       step_names     state    event  \
# binary_index
# 0             8.986912e+09     initial_cond  detached     ZAMS
# 0             8.999785e+09     step_HMS_HMS      RLO1     oCE1
# 0             8.999785e+09          step_CE  detached      NaN
# 0             8.999790e+09    step_detached  detached      CC1
# 0             8.999790e+09          step_SN  detached      NaN
# ...                    ...              ...       ...      ...
# 106           7.274039e+09    step_detached      RLO2    oRLO2
# 106           7.469879e+09  step_CO_HMS_RLO  detached      CC2
# 106           7.469879e+09          step_SN  detached      NaN
# 106           1.380000e+10         step_dco  detached  maxtime
# 106           1.380000e+10         step_end  detached      END
#
#                                   S1_state                 S2_state  \
# binary_index
# 0                    H-rich_Core_H_burning    H-rich_Core_H_burning
# ...

# %%
df = pd.read_csv('/home/bku2126/b1095/bku2126/stellarBHs/Data/10MillFilt/BH_Sol_Filtered_1e+00_Zsun_population.csv')

# %%
df
# Out:
#      binary_index     state event          time  separation  orbital_period  \
# 0           98167  detached   NaN  8.999790e+09   15.592295        2.759667
# 1          164933  detached   NaN  5.320878e+09   23.548169        5.665033
# 2          421025  detached   NaN  8.501130e+09   56.874522       19.815499
# 3          432008  detached   NaN  7.629853e+07    6.833317        0.876181
# 4          469540  detached   NaN  4.671309e+09   30.960643        7.931873
# ..            ...       ...   ...           ...         ...             ...
# 102       9869876  detached   NaN  7.958286e+09  176.651172      109.989868
# 103       9893810  detached   NaN  5.797456e+09   47.100819       13.746755
# 104       9898281  detached   NaN  6.978108e+09   28.385943        6.730866
# 105       9912445  detached   NaN  3.801350e+09   84.011404       36.878780
# 106       9914475  detached   NaN  6.808599e+09  155.913807       84.545141
#
# ...

# %%
pop.oneline.select()
# Out:
#                state_i event_i        time_i  orbital_period_i  \
# binary_index
# 0             detached    ZAMS  1.127619e+10          7.882748
# 1             detached    ZAMS  5.837792e+09         53.448491
# 2             detached    ZAMS  9.932242e+09       2916.894296
# 3             detached    ZAMS  9.678377e+09        199.614917
# 4             detached    ZAMS  5.456018e+09         92.135975
# ...                ...     ...           ...               ...
# 264596        detached    ZAMS  6.029655e+09        239.191571
# 264597        detached    ZAMS  5.553193e+09        674.308961
# 264598        detached    ZAMS  7.110186e+09        444.728885
# 264599        detached    ZAMS  7.026118e+09         65.105656
# 264600        detached    ZAMS  5.681885e+09        164.264850
#
#               eccentricity_i  lg_mtransfer_rate_i  step_names_i  step_times_i  \
# binary_index
# 0                   0.071952                  NaN  initial_cond           0.0
# ...

# %%
bhSolPop.oneline.select()
# Out:
#                state_i event_i        time_i  separation_i  orbital_period_i  \
# binary_index
# 0             detached    ZAMS  8.986912e+09   2919.300237       4138.854009
# 1             detached    ZAMS  5.307688e+09   2931.796105       4214.058792
# 2             detached    ZAMS  8.486257e+09   2845.924808       4123.090826
# 3             detached    ZAMS  6.315842e+07   2981.541957       4342.833283
# 4             detached    ZAMS  4.657077e+09   2877.764076       4127.376889
# ...                ...     ...           ...           ...               ...
# 102           detached    ZAMS  7.942877e+09   2845.694725       4159.486756
# 103           detached    ZAMS  5.785051e+09   2896.943115       3966.766286
# 104           detached    ZAMS  6.964517e+09   2879.043280       4059.758619
# 105           detached    ZAMS  3.786517e+09   2912.513384       4308.784509
# 106           detached    ZAMS  6.794610e+09   2838.121518       3989.468034
#
# ...

# %%
bhSolPop.oneline.select()[initCols].describe()
# Out:
#        orbital_period_i  eccentricity_i   S2_mass_i  S2_log_R_i   S1_mass_i  \
# count        107.000000           107.0  107.000000       107.0  107.000000
# mean        4079.427748             0.0    2.269078         0.0   16.729035
# std          576.479870             0.0    0.554295         0.0    1.008902
# min           17.828069             0.0    1.615385         0.0   14.601914
# 25%         4032.185001             0.0    1.967630         0.0   16.000921
# 50%         4161.095349             0.0    2.224593         0.0   16.618007
# 75%         4271.339436             0.0    2.451451         0.0   17.282941
# max         4392.380851             0.0    6.285087         0.0   21.171676
#
#        S1_log_R_i
# count       107.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0

# %%
df = pop.history.select()
df2 = df[df['step_names'] =='step_CE']

# %%
df = df2[df2['state'] =='merged']

# %%
# df.to_csv('/home/bku2126/b1095/bku2126/stellarBHs/Data/merging.csv')

# %%
### merged pop

pop_merged = Population(str(DataPath / '/home/bku2126/b1095/bku2126/stellarBHs/Data/oneMillMerged.h5'))

pOneline_merged = pop_merged.oneline.select()

pHistory_merged = pop_merged.history.select()

# %%
pOneline_merged = pOneline_merged[pOneline_merged['S1_mass_i'] > 10]
pOneline_merged = pOneline_merged[pOneline_merged['S1_mass_i'] < 22]

pOneline_merged = pOneline_merged[pOneline_merged['S2_mass_i'] > 1]
pOneline_merged = pOneline_merged[pOneline_merged['S2_mass_i'] < 7]

pOneline_merged= pOneline_merged[pOneline_merged['orbital_period_i'] > 3800]
pOneline_merged= pOneline_merged[pOneline_merged['orbital_period_i'] < 4400]

pOneline_merged_sample = pOneline_merged

# %%
pOneline_merged_sample

pop_merged.export_selection(pOneline_merged_sample.index.to_list(), '/home/bku2126/b1095/bku2126/stellarBHs/Data/failedSystems_wideConstrain.h5', overwrite=True)

# %%
oneline10 = pop10.oneline.select()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 oneline10 = pop10.oneline.select()
#
# NameError: name 'pop10' is not defined

# %%
oneline10[initCols]['S2_mass_i'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 oneline10[initCols]['S2_mass_i'].describe()
#
# NameError: name 'oneline10' is not defined

# %%
oneline10[initCols]['S1_mass_i'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 oneline10[initCols]['S1_mass_i'].describe()
#
# NameError: name 'oneline10' is not defined

# %%
Counter(pop.formation_channels['channel'])
# Out:
# Counter({'ZAMS_CC1_END': 297605,
#          'ZAMS_oCE1_oMerging1_CC1_END': 233639,
#          'ZAMS_oRLO1_CC1_CC2_END': 173762,
#          'ZAMS_oRLO1_CC1_oRLO2_CC2_END': 57603,
#          'ZAMS_CC1_CC2_END': 48012,
#          'ZAMS_oRLO1_CC1_oRLO2_CC2_maxtime_END': 34596,
#          'ZAMS_oRLO1_CC1_oRLO2_oCE2_oMerging2_END': 17539,
#          'ZAMS_oCE1_END': 16979,
#          'ZAMS_FAILED_FAILED': 15966,
#          'ZAMS_CC1_oRLO2_CC2_END': 15540,
#          'ZAMS_oRLO1_CC1_END': 14225,
#          'ZAMS_oCE1_CC1_CC2_END': 12570,
#          'ZAMS_CC1_oRLO2_CC2_maxtime_END': 11591,
#          'ZAMS_oCE2_oMerging2_CC2_END': 7906,
#          'ZAMS_oRLO1-reverse_CC1_CC2_END': 6264,
#          'ZAMS_oCE1_FAILED_FAILED': 4566,
#          'ZAMS_oRLO1_CC1_oRLO2_oCE2_CC2_END': 4383,
#          'ZAMS_CC1_CC2_maxtime_END': 3861,
#          'ZAMS_oCE1_CC1_oRLO2_oCE2_oMerging2_END': 2949,
#          'ZAMS_oRLO1-reverse_CC1_CC2_maxtime_END': 2933,
#          'ZAMS_oCE1_CC1_END': 2326,
# ...

# %%
fc = pop.formation_channels

mask = fc['channel'] == 'ZAMS_oCE1_oMerging1_CC1_END'

binary_indices= fc[mask].index.tolist()

# %%
pop.history[binary_indices][cols]
# Out:
#                       time    step_names     state      event  \
# binary_index
# 11            1.127619e+10  initial_cond  detached       ZAMS
# 11            1.128775e+10  step_HMS_HMS      RLO1       oCE1
# 11            1.128775e+10       step_CE    merged  oMerging1
# 11            1.128950e+10   step_merged    merged        CC1
# 11            1.128950e+10       step_SN    merged        NaN
# ...                    ...           ...       ...        ...
# 999993        5.693361e+09  step_HMS_HMS      RLO1       oCE1
# 999993        5.693361e+09       step_CE    merged  oMerging1
# 999993        5.694012e+09   step_merged    merged        CC1
# 999993        5.694012e+09       step_SN    merged        NaN
# 999993        5.694012e+09      step_end    merged        END
#
#                             S1_state               S2_state    S1_mass  \
# binary_index
# 11             H-rich_Core_H_burning  H-rich_Core_H_burning  17.031616
# ...

# %%
merged = pop.oneline.select("state_f == merged")

# %%
pop.export_selection(merged.index.to_list(), 'test.h5')
