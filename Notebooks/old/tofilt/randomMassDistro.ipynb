# %%
import pandas as pd
from pathlib import Path
import numpy as np
import seaborn as sns
import random as rand
# from posydon.popsyn.binarypopulation import BinaryPopulation
# from posydon.binary_evol.binarystar import BinaryStar
# from posydon.binary_evol.singlestar import SingleStar
from posydon.popsyn.synthetic_population import Population
# from posydon.popsyn.synthetic_population import PopulationRunner
# import astropy.units as u
# 
# import os
# import shutil
# from posydon.config import PATH_TO_POSYDON

from POSYDONHRDiagramModule import HR_Diagram

import matplotlib.pyplot as plt
import matplotlib as mpl

import random as rand 

from collections import Counter

DataPath = Path().resolve().parent / 'Data'

# %%
cols = ['time', 'step_names', 'state', 'event', 'S1_state', 'S2_state', 'S1_mass', 'S2_mass', 'orbital_period']
finCols = [
    'orbital_period_f',
    'eccentricity_f',
    'state_f',

    'S1_state_f',
    'S2_state_f',
    
    'S2_mass_f',
    'S2_log_R_f',
    'S2_log_L_f',


    'S1_mass_f',
    'S1_log_R_f',
    'S1_log_L_f'

 ]

initCols = [
    'orbital_period_i',
    'eccentricity_i',
    'state_i',

    'S2_state_i',
    'S2_mass_i',
    'S2_log_R_i',

    'S1_state_i',
    'S1_mass_i',
    'S1_log_R_i'
 ]

# %%
mpl.rcParams.update({
    "pgf.texsystem": "pdflatex",  
    "font.family": "serif",       
    "text.usetex": True,          
    "pgf.rcfonts": False,         
})

# %%
def basicColHist(df, var: str, title: str | None = None, xLabel: str | None = None, saveFig: bool = False, savePath: Path = Path()) -> None:
    fig, ax = plt.subplots(figsize=(8,5))
    
    sns.histplot(df[var], bins=50, ax=ax)
    
    if title is None:
        title = f'{var} of BH-Sol systems at S1 SN'
    if xLabel is None:
        xLabel = var

    ax.set_title(title)
    ax.set_xlabel(xLabel)
    ax.set_ylabel('Count')

    if saveFig:
        clean_name = title.replace(' ', '_').replace('/', '-') + '.pgf'
        plt.savefig(savePath / clean_name, bbox_inches='tight')

    plt.show()

def genVarHist(var: list, title: str | None = None, xLabel: str | None = None, saveFig: bool = False, savePath: Path = Path()) -> None:
    fig, ax = plt.subplots(figsize=(8,5))
    
    sns.histplot(var, bins=50, ax=ax)
    
    if title is None:
        title = 'default'
    if xLabel is None:
        xLabel = 'default'

    ax.set_title(title)
    ax.set_xlabel(xLabel)
    ax.set_ylabel('Count')

    if saveFig:
        clean_name = title.replace(' ', '_').replace('/', '-') + '.pgf'
        plt.savefig(savePath / clean_name, bbox_inches='tight')

    plt.show()

# %%
def xVsY(
    xvar: str|list, yvar: str|list,
    df: pd.DataFrame | None = None,
    useDF: bool = True, 
    title: str | None = None,
    xLabel: str | None = None,
    yLabel: str | None = None,
    saveFig: bool = False,
    savePath: Path = Path(),
    fit: bool = False,
    ci: int = 95
) -> None:
    fig, ax = plt.subplots(figsize=(8, 5))

    if useDF:
        x = df[xvar] if isinstance(xvar, str) else xvar
        y = df[yvar] if isinstance(yvar, str) else yvar
    else:
        x, y = xvar, yvar  
        
    if fit:
        sns.regplot(x=x, y=y, ci=ci, ax=ax,
                    line_kws={"color": "red", "linestyle": "--", "linewidth": 2},
                    scatter_kws={"alpha": 0.6})
    else:
        sns.scatterplot(x=x, y=y, alpha=0.6, ax=ax)

    if title is None:
        if isinstance(xvar, str) and isinstance(yvar, str):
            title = f'{xvar} vs {yvar} of BH-Sol systems at S1 SN'
        else:
            title = 'Variable Comparison'

    if xLabel is None:
        xLabel = xvar if isinstance(xvar, str) else 'X-Axis'
        
    if yLabel is None:
        yLabel = yvar if isinstance(yvar, str) else 'Y-Axis'

    ax.set_title(title)
    ax.set_xlabel(xLabel)
    ax.set_ylabel(yLabel)

    if saveFig:
        clean_name = title.replace(' ', '_').replace('/', '-') + '.pgf'
        plt.savefig(savePath / clean_name, bbox_inches='tight')

    plt.show()

# %%
pop = Population(str(DataPath / 'RandInitMassDistro' / 'BH_Sol_Filtered_1e+00_Zsun_population.h5'))
bhSolRows = pd.read_csv(DataPath /'RandInitMassDistro' / 'BH_Sol_Filtered_1e+00_Zsun_population.csv')

# %%
bhSolRows.loc[31]
# Out:
# binary_index                                                                   780625
# state                                                                        detached
# event                                                                             NaN
# time                                                                7670404632.984411
# orbital_period                                                             183.139676
# eccentricity                                                                 0.854321
# lg_mtransfer_rate                                                                 NaN
# step_names                                                                    step_SN
# step_times                                                                   0.001354
# S1_state                                                                           BH
# S1_mass                                                                      2.577795
# S1_log_R                                                                    -4.960877
# S1_log_L                                                                          NaN
# S1_lg_mdot                                                                        NaN
# S1_he_core_mass                                                                   NaN
# S1_he_core_radius                                                                 NaN
# S1_co_core_mass                                                              5.239305
# S1_co_core_radius                                                                 NaN
# S1_center_h1                                                                      NaN
# S1_center_he4                                                                     NaN
# S1_surface_h1                                                                     NaN
# S1_surface_he4                                                                    NaN
# S1_surf_avg_omega_div_omega_crit                                                  NaN
# S1_spin                                                                           0.0
# S1_envelope_binding_energy                                                        NaN
# S2_state                                                        H-rich_Core_H_burning
# S2_mass                                                                      2.183746
# S2_log_R                                                                     0.205504
# S2_log_L                                                                     1.410663
# S2_lg_mdot                                                                        NaN
# S2_he_core_mass                                                                   0.0
# S2_he_core_radius                                                                 NaN
# S2_co_core_mass                                                                   0.0
# S2_co_core_radius                                                                 0.0
# S2_center_h1                                                                 0.702056
# S2_center_he4                                                                0.283429
# S2_surface_h1                                                                  0.7155
# S2_surface_he4                                                               0.270271
# S2_surf_avg_omega_div_omega_crit                                             0.021841
# S2_spin                                                                      0.613922
# S2_envelope_binding_energy         -1057808286347786000188194229580258151887932489...
# Name: 31, dtype: object

# %%
pop.calculate_formation_channels()
# Out:
# Formation channels already exist in the parsed population file!
# Channels will be overwriten

# %%
Counter(pop.formation_channels['channel'])
# Out:
# Counter({'ZAMS_oCE1_CC1_oRLO2_CC2_maxtime_END': 28,
#          'ZAMS_oRLO1_CC1_oRLO2_CC2_FAILED': 3,
#          'ZAMS_oCE1_CC1_END': 3,
#          'ZAMS_oCE1_CC1_oRLO2_maxtime_END': 1})

# %%
pOneline = pop.oneline.select()
pHistory = pop.history.select()

# %%
bhSolRows[cols]
# Out:
#             time       step_names     state event S1_state  \
# 0   7.577646e+09          step_SN  detached   NaN       BH
# 1   6.170268e+09          step_SN  detached   NaN       BH
# 2   2.859038e+09          step_SN  detached   NaN       BH
# 3   1.356700e+09          step_SN  detached   NaN       BH
# 4   7.117764e+09          step_SN  detached   NaN       BH
# 5   6.077691e+09          step_SN  detached   NaN       BH
# 6   8.567795e+09  step_CO_HMS_RLO  detached   CC2       BH
# 7   6.055485e+09          step_SN  detached   NaN       BH
# 8   5.466712e+09  step_CO_HMS_RLO  detached   CC2       BH
# 9   4.574378e+09          step_SN  detached   NaN       BH
# 10  2.834482e+09  step_CO_HMS_RLO  detached   CC2       BH
# 11  1.245802e+09          step_SN  detached   NaN       BH
# 12  3.900484e+09          step_SN  detached   NaN       BH
# 13  5.990171e+09          step_SN  detached   NaN       BH
# 14  6.239882e+09          step_SN  detached   NaN       BH
# 15  7.419283e+09          step_SN  detached   NaN       BH
# 16  6.911943e+09          step_SN  detached   NaN       BH
# 17  2.419455e+09          step_SN  detached   NaN       BH
# 18  8.924418e+09          step_SN  detached   NaN       BH
# 19  3.536011e+09          step_SN  detached   NaN       BH
# 20  3.422426e+09          step_SN  detached   NaN       BH
# 21  5.744890e+09          step_SN  detached   NaN       BH
# 22  6.009091e+09          step_SN  detached   NaN       BH
# 23  9.189510e+09          step_SN  detached   NaN       BH
# 24  9.091932e+09          step_SN  detached   NaN       BH
# 25  2.437457e+09          step_SN  detached   NaN       BH
# 26  9.386213e+09          step_SN  detached   NaN       BH
# 27  7.786103e+09          step_SN  detached   NaN       BH
# 28  1.600740e+09          step_SN  detached   NaN       BH
# 29  6.616770e+09          step_SN  detached   NaN       BH
# 30  3.035263e+09          step_SN  detached   NaN       BH
# 31  7.670405e+09          step_SN  detached   NaN       BH
# 32  1.823277e+09          step_SN  detached   NaN       BH
# 33  6.779764e+09          step_SN  detached   NaN       BH
# 34  7.220835e+09          step_SN  detached   NaN       BH
#
#                  S2_state   S1_mass   S2_mass  orbital_period
# 0   H-rich_Core_H_burning  3.630864  2.951579        2.204112
# 1   H-rich_Core_H_burning  3.893836  2.212253       19.419203
# 2   H-rich_Core_H_burning  4.662208  2.490961        5.627132
# 3   H-rich_Core_H_burning  3.623690  2.809736      206.012218
# 4   H-rich_Core_H_burning  2.577795  2.904845       14.115405
# 5   H-rich_Core_H_burning  3.747091  2.331258       11.413994
# 6   H-rich_Core_H_burning  2.820388  0.415740       11.468097
# 7   H-rich_Core_H_burning  4.847438  2.659875       13.732631
# 8   H-rich_Core_H_burning  3.905661  0.412384       13.631720
# 9   H-rich_Core_H_burning  3.747189  2.188533        2.435045
# 10  H-rich_Core_H_burning  3.855988  0.420167       13.422858
# 11  H-rich_Core_H_burning  3.902887  2.917116        3.275211
# 12  H-rich_Core_H_burning  4.109753  2.493445       32.500149
# 13  H-rich_Core_H_burning  4.575038  2.585677       31.187495
# 14  H-rich_Core_H_burning  2.577795  2.529788        5.554187
# 15  H-rich_Core_H_burning  3.843141  1.894437        5.274121
# 16  H-rich_Core_H_burning  3.842706  2.002507       13.532947
# 17  H-rich_Core_H_burning  4.337124  2.621485        0.758984
# 18  H-rich_Core_H_burning  3.623080  2.087605        8.628589
# 19  H-rich_Core_H_burning  3.162897  2.906934        2.633313
# 20  H-rich_Core_H_burning  3.136480  1.852127       36.132301
# 21  H-rich_Core_H_burning  4.321676  2.059718       26.936653
# 22  H-rich_Core_H_burning  3.141697  2.658828       48.481993
# 23  H-rich_Core_H_burning  4.636622  2.924453        3.840693
# 24  H-rich_Core_H_burning  4.671592  2.634065        6.427261
# 25  H-rich_Core_H_burning  3.746490  1.874973        7.095680
# 26  H-rich_Core_H_burning  4.325017  2.845116       19.074911
# 27  H-rich_Core_H_burning  4.554425  2.377651        3.788966
# 28  H-rich_Core_H_burning  3.844683  1.990694       11.235822
# 29  H-rich_Core_H_burning  4.490669  2.390161       11.957325
# 30  H-rich_Core_H_burning  4.337121  2.373906       98.243863
# 31  H-rich_Core_H_burning  2.577795  2.183746      183.139676
# 32  H-rich_Core_H_burning  4.661670  2.623492        9.001092
# 33  H-rich_Core_H_burning  3.933245  2.760904       51.016130
# 34  H-rich_Core_H_burning  4.165837  2.373879        1.613982

# %%
dropI = pOneline[pOneline['S2_mass_i'] > 3].index.to_list()

# %%
pOneline
# Out:
#                state_i event_i        time_i  orbital_period_i  \
# binary_index
# 0             detached    ZAMS  7.566254e+09       3839.006548
# 1             detached    ZAMS  6.155214e+09       4223.795575
# 2             detached    ZAMS  2.846162e+09       4058.280977
# 3             detached    ZAMS  1.343257e+09       4089.658141
# 4             detached    ZAMS  7.103941e+09       3919.298539
# 5             detached    ZAMS  6.063214e+09       4017.650356
# 6             detached    ZAMS  8.258747e+09         38.904651
# 7             detached    ZAMS  6.044086e+09       3992.854453
# 8             detached    ZAMS  4.647674e+09         16.582671
# 9             detached    ZAMS  4.561423e+09       4116.950745
# 10            detached    ZAMS  2.077646e+09         17.336475
# 11            detached    ZAMS  1.234784e+09       3863.523618
# 12            detached    ZAMS  3.885615e+09       4094.989533
# 13            detached    ZAMS  5.976924e+09       3987.244087
# 14            detached    ZAMS  6.225220e+09       3961.577991
# 15            detached    ZAMS  7.404801e+09       4356.343911
# 16            detached    ZAMS  6.896613e+09       4236.572228
# 17            detached    ZAMS  2.407939e+09       3974.099569
# 18            detached    ZAMS  8.908872e+09       4326.926534
# 19            detached    ZAMS  3.523942e+09       3858.976882
# 20            detached    ZAMS  3.405930e+09       4332.201793
# 21            detached    ZAMS  5.731482e+09       4216.358193
# 22            detached    ZAMS  5.996639e+09       4160.724402
# 23            detached    ZAMS  9.178600e+09       3943.454724
# 24            detached    ZAMS  9.080135e+09       3982.536012
# 25            detached    ZAMS  2.422293e+09       4266.473367
# 26            detached    ZAMS  9.372251e+09       3965.837525
# 27            detached    ZAMS  7.773706e+09       4137.196660
# 28            detached    ZAMS  1.585736e+09       4257.987232
# 29            detached    ZAMS  6.604763e+09       4077.560647
# 30            detached    ZAMS  3.023070e+09       4132.647251
# 31            detached    ZAMS  7.654171e+09       4036.458301
# 32            detached    ZAMS  1.810137e+09       4048.716877
# 33            detached    ZAMS  6.765034e+09       3991.347573
# 34            detached    ZAMS  7.207836e+09       4037.381419
#
#               eccentricity_i  lg_mtransfer_rate_i  step_names_i  step_times_i  \
# binary_index
# 0                        0.0                  NaN  initial_cond           0.0
# 1                        0.0                  NaN  initial_cond           0.0
# 2                        0.0                  NaN  initial_cond           0.0
# 3                        0.0                  NaN  initial_cond           0.0
# 4                        0.0                  NaN  initial_cond           0.0
# 5                        0.0                  NaN  initial_cond           0.0
# 6                        0.0                  NaN  initial_cond           0.0
# 7                        0.0                  NaN  initial_cond           0.0
# 8                        0.0                  NaN  initial_cond           0.0
# 9                        0.0                  NaN  initial_cond           0.0
# 10                       0.0                  NaN  initial_cond           0.0
# 11                       0.0                  NaN  initial_cond           0.0
# 12                       0.0                  NaN  initial_cond           0.0
# 13                       0.0                  NaN  initial_cond           0.0
# 14                       0.0                  NaN  initial_cond           0.0
# 15                       0.0                  NaN  initial_cond           0.0
# 16                       0.0                  NaN  initial_cond           0.0
# 17                       0.0                  NaN  initial_cond           0.0
# 18                       0.0                  NaN  initial_cond           0.0
# 19                       0.0                  NaN  initial_cond           0.0
# 20                       0.0                  NaN  initial_cond           0.0
# 21                       0.0                  NaN  initial_cond           0.0
# 22                       0.0                  NaN  initial_cond           0.0
# 23                       0.0                  NaN  initial_cond           0.0
# 24                       0.0                  NaN  initial_cond           0.0
# 25                       0.0                  NaN  initial_cond           0.0
# 26                       0.0                  NaN  initial_cond           0.0
# 27                       0.0                  NaN  initial_cond           0.0
# 28                       0.0                  NaN  initial_cond           0.0
# 29                       0.0                  NaN  initial_cond           0.0
# 30                       0.0                  NaN  initial_cond           0.0
# 31                       0.0                  NaN  initial_cond           0.0
# 32                       0.0                  NaN  initial_cond           0.0
# 33                       0.0                  NaN  initial_cond           0.0
# 34                       0.0                  NaN  initial_cond           0.0
#
#                          S1_state_i  S1_mass_i  ...  interp_class_CO_HMS_RLO  \
# binary_index                                    ...
# 0             H-rich_Core_H_burning  18.631433  ...                stable_MT
# 1             H-rich_Core_H_burning  15.936004  ...                stable_MT
# 2             H-rich_Core_H_burning  17.552171  ...                stable_MT
# 3             H-rich_Core_H_burning  16.826815  ...                stable_MT
# 4             H-rich_Core_H_burning  16.359727  ...                stable_MT
# 5             H-rich_Core_H_burning  16.290342  ...                stable_MT
# 6             H-rich_Core_H_burning  18.986692  ...                stable_MT
# 7             H-rich_Core_H_burning  18.859999  ...                stable_MT
# 8             H-rich_Core_H_burning  22.835219  ...                stable_MT
# 9             H-rich_Core_H_burning  17.136343  ...                stable_MT
# 10            H-rich_Core_H_burning  21.676431  ...                stable_MT
# 11            H-rich_Core_H_burning  19.134812  ...                stable_MT
# 12            H-rich_Core_H_burning  16.167678  ...                stable_MT
# 13            H-rich_Core_H_burning  17.346577  ...                stable_MT
# 14            H-rich_Core_H_burning  15.875444  ...                      NaN
# 15            H-rich_Core_H_burning  16.159012  ...                stable_MT
# 16            H-rich_Core_H_burning  15.755334  ...                stable_MT
# 17            H-rich_Core_H_burning  18.632966  ...                      NaN
# 18            H-rich_Core_H_burning  15.565203  ...                      NaN
# 19            H-rich_Core_H_burning  17.850958  ...                stable_MT
# 20            H-rich_Core_H_burning  15.042657  ...                stable_MT
# 21            H-rich_Core_H_burning  16.997240  ...                stable_MT
# 22            H-rich_Core_H_burning  17.408301  ...                stable_MT
# 23            H-rich_Core_H_burning  19.416319  ...                stable_MT
# 24            H-rich_Core_H_burning  18.511753  ...                stable_MT
# 25            H-rich_Core_H_burning  15.820942  ...                stable_MT
# 26            H-rich_Core_H_burning  16.809423  ...                stable_MT
# 27            H-rich_Core_H_burning  17.846105  ...                stable_MT
# 28            H-rich_Core_H_burning  15.927700  ...                stable_MT
# 29            H-rich_Core_H_burning  18.225564  ...                stable_MT
# 30            H-rich_Core_H_burning  18.015463  ...                stable_MT
# 31            H-rich_Core_H_burning  15.083546  ...                stable_MT
# 32            H-rich_Core_H_burning  17.370093  ...                stable_MT
# 33            H-rich_Core_H_burning  16.245418  ...                stable_MT
# 34            H-rich_Core_H_burning  17.294743  ...                stable_MT
#
#               interp_class_CO_HeMS  interp_class_CO_HeMS_RLO  \
# binary_index
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# 5                              NaN                       NaN
# 6                              NaN                       NaN
# 7                              NaN                       NaN
# 8                              NaN                       NaN
# 9                              NaN                       NaN
# 10                             NaN                       NaN
# 11                             NaN                       NaN
# 12                             NaN                       NaN
# 13                             NaN                       NaN
# 14                             NaN                       NaN
# 15                             NaN                       NaN
# 16                             NaN                       NaN
# 17                             NaN                       NaN
# 18                             NaN                       NaN
# 19                             NaN                       NaN
# 20                             NaN                       NaN
# 21                             NaN                       NaN
# 22                             NaN                       NaN
# 23                             NaN                       NaN
# 24                             NaN                       NaN
# 25                             NaN                       NaN
# 26                             NaN                       NaN
# 27                             NaN                       NaN
# 28                             NaN                       NaN
# 29                             NaN                       NaN
# 30                             NaN                       NaN
# 31                             NaN                       NaN
# 32                             NaN                       NaN
# 33                             NaN                       NaN
# 34                             NaN                       NaN
#
#                           mt_history_HMS_HMS           mt_history_CO_HMS_RLO  \
# binary_index
# 0                Unstable RLOF during postMS  Last stable RLOF during postMS
# 1                Unstable RLOF during postMS  Last stable RLOF during postMS
# 2                Unstable RLOF during postMS  Last stable RLOF during postMS
# 3                Unstable RLOF during postMS  Last stable RLOF during postMS
# 4                Unstable RLOF during postMS  Last stable RLOF during postMS
# 5                Unstable RLOF during postMS  Last stable RLOF during postMS
# 6             Last stable RLOF during postMS  Last stable RLOF during postMS
# 7                Unstable RLOF during postMS  Last stable RLOF during postMS
# 8             Last stable RLOF during postMS  Last stable RLOF during postMS
# 9                Unstable RLOF during postMS  Last stable RLOF during postMS
# 10            Last stable RLOF during postMS  Last stable RLOF during postMS
# 11               Unstable RLOF during postMS  Last stable RLOF during postMS
# 12               Unstable RLOF during postMS  Last stable RLOF during postMS
# 13               Unstable RLOF during postMS  Last stable RLOF during postMS
# 14               Unstable RLOF during postMS                             NaN
# 15               Unstable RLOF during postMS  Last stable RLOF during postMS
# 16               Unstable RLOF during postMS  Last stable RLOF during postMS
# 17               Unstable RLOF during postMS                             NaN
# 18               Unstable RLOF during postMS                             NaN
# 19               Unstable RLOF during postMS  Last stable RLOF during postMS
# 20               Unstable RLOF during postMS  Last stable RLOF during postMS
# 21               Unstable RLOF during postMS  Last stable RLOF during postMS
# 22               Unstable RLOF during postMS  Last stable RLOF during postMS
# 23               Unstable RLOF during postMS  Last stable RLOF during postMS
# 24               Unstable RLOF during postMS  Last stable RLOF during postMS
# 25               Unstable RLOF during postMS  Last stable RLOF during postMS
# 26               Unstable RLOF during postMS  Last stable RLOF during postMS
# 27               Unstable RLOF during postMS  Last stable RLOF during postMS
# 28               Unstable RLOF during postMS  Last stable RLOF during postMS
# 29               Unstable RLOF during postMS  Last stable RLOF during postMS
# 30               Unstable RLOF during postMS  Last stable RLOF during postMS
# 31               Unstable RLOF during postMS  Last stable RLOF during postMS
# 32               Unstable RLOF during postMS  Last stable RLOF during postMS
# 33               Unstable RLOF during postMS  Last stable RLOF during postMS
# 34               Unstable RLOF during postMS  Last stable RLOF during postMS
#
#               mt_history_CO_HeMS  mt_history_CO_HeMS_RLO  FAILED  WARNING  \
# binary_index
# 0                            NaN                     NaN       0        1
# 1                            NaN                     NaN       0        1
# 2                            NaN                     NaN       0        1
# 3                            NaN                     NaN       0        1
# 4                            NaN                     NaN       0        1
# 5                            NaN                     NaN       0        1
# 6                            NaN                     NaN       1        1
# 7                            NaN                     NaN       0        1
# 8                            NaN                     NaN       1        1
# 9                            NaN                     NaN       0        1
# 10                           NaN                     NaN       1        0
# 11                           NaN                     NaN       0        1
# 12                           NaN                     NaN       0        1
# 13                           NaN                     NaN       0        1
# 14                           NaN                     NaN       0        1
# 15                           NaN                     NaN       0        1
# 16                           NaN                     NaN       0        1
# 17                           NaN                     NaN       0        1
# 18                           NaN                     NaN       0        1
# 19                           NaN                     NaN       0        1
# 20                           NaN                     NaN       0        1
# 21                           NaN                     NaN       0        1
# 22                           NaN                     NaN       0        1
# 23                           NaN                     NaN       0        1
# 24                           NaN                     NaN       0        1
# 25                           NaN                     NaN       0        1
# 26                           NaN                     NaN       0        1
# 27                           NaN                     NaN       0        1
# 28                           NaN                     NaN       0        1
# 29                           NaN                     NaN       0        1
# 30                           NaN                     NaN       0        1
# 31                           NaN                     NaN       0        1
# 32                           NaN                     NaN       0        1
# 33                           NaN                     NaN       0        1
# 34                           NaN                     NaN       0        1
#
#               metallicity
# binary_index
# 0                     1.0
# 1                     1.0
# 2                     1.0
# 3                     1.0
# 4                     1.0
# 5                     1.0
# 6                     1.0
# 7                     1.0
# 8                     1.0
# 9                     1.0
# 10                    1.0
# 11                    1.0
# 12                    1.0
# 13                    1.0
# 14                    1.0
# 15                    1.0
# 16                    1.0
# 17                    1.0
# 18                    1.0
# 19                    1.0
# 20                    1.0
# 21                    1.0
# 22                    1.0
# 23                    1.0
# 24                    1.0
# 25                    1.0
# 26                    1.0
# 27                    1.0
# 28                    1.0
# 29                    1.0
# 30                    1.0
# 31                    1.0
# 32                    1.0
# 33                    1.0
# 34                    1.0
#
# [35 rows x 113 columns]

# %%
bhSolRows[bhSolRows['orbital_period'] > 150][cols]
# Out:
#             time step_names     state event S1_state               S2_state  \
# 3   1.356700e+09    step_SN  detached   NaN       BH  H-rich_Core_H_burning
# 31  7.670405e+09    step_SN  detached   NaN       BH  H-rich_Core_H_burning
#
#      S1_mass   S2_mass  orbital_period
# 3   3.623690  2.809736      206.012218
# 31  2.577795  2.183746      183.139676

# %%
pHistory.loc[3]
# Out:
#                  state    event          time  orbital_period  eccentricity  \
# binary_index
# 3             detached     ZAMS  1.343257e+09     4089.658141      0.000000
# 3                 RLO1     oCE1  1.356695e+09     3561.885739      0.000000
# 3             detached      NaN  1.356695e+09        4.500286      0.000000
# 3             detached      CC1  1.356700e+09        4.512287      0.000000
# 3             detached      NaN  1.356700e+09      206.012218      0.910055
# 3                 RLO2    oRLO2  1.739471e+09        5.558220      0.000000
# 3             detached      CC2  1.910741e+09      249.145476      0.000000
# 3             detached      NaN  1.910741e+09      254.279121      0.000000
# 3             detached  maxtime  1.380000e+10      254.279110      0.000000
# 3             detached      END  1.380000e+10      254.279110      0.000000
#
#               lg_mtransfer_rate       step_names  step_times  \
# binary_index
# 3                           NaN     initial_cond    0.000000
# 3                     -1.590285     step_HMS_HMS    0.081932
# 3                           NaN          step_CE    0.000167
# 3                           NaN    step_detached    0.405496
# 3                           NaN          step_SN    0.003542
# 3                           NaN    step_detached    0.298575
# 3                    -99.000000  step_CO_HMS_RLO    0.064817
# 3                           NaN          step_SN    0.000105
# 3                           NaN         step_dco    0.016121
# 3                           NaN         step_end    0.000037
#
#                                   S1_state    S1_mass  ...  S2_he_core_radius  \
# binary_index                                           ...
# 3                    H-rich_Core_H_burning  16.826815  ...                NaN
# 3                  H-rich_Core_He_depleted  10.953986  ...           0.000000
# 3             stripped_He_Core_He_depleted   7.410050  ...           0.000000
# 3              stripped_He_Core_C_depleted   7.322213  ...                NaN
# 3                                       BH   3.623690  ...                NaN
# 3                                       BH   3.623690  ...                NaN
# 3                                       BH   4.381564  ...           0.014982
# 3                                       BH   4.381564  ...                NaN
# 3                                       BH   4.381564  ...                NaN
# 3                                       BH   4.381564  ...                NaN
#
#               S2_co_core_mass  S2_co_core_radius  S2_center_h1  S2_center_he4  \
# binary_index
# 3                         NaN                NaN      0.715500   2.703000e-01
# 3                    0.000000           0.000000      0.700188   2.854706e-01
# 3                    0.000000           0.000000      0.700188   2.854706e-01
# 3                    0.000000           0.000000      0.694111   2.914958e-01
# 3                    0.000000           0.000000      0.694111   2.914958e-01
# 3                    0.000000           0.000000      0.000000   9.861392e-01
# 3                    0.471471           0.010888      0.000000   1.754333e-29
# 3                    0.469570                NaN      0.000000   1.754333e-29
# 3                    0.469570                NaN      0.000000   1.754333e-29
# 3                    0.469570                NaN      0.000000   1.754333e-29
#
#               S2_surface_h1  S2_surface_he4  S2_surf_avg_omega_div_omega_crit  \
# binary_index
# 3                       NaN             NaN                               NaN
# 3                  0.683112        0.302642                          0.976972
# 3                  0.683112        0.302642                          0.976972
# 3                  0.715500        0.270271                          0.057749
# 3                  0.715500        0.270271                          0.057749
# 3                  0.715500        0.270271                          0.074467
# 3                  0.597618        0.388286                          0.000181
# 3                       NaN             NaN                               NaN
# 3                       NaN             NaN                          0.000000
# 3                       NaN             NaN                          0.000000
#
#                S2_spin  S2_envelope_binding_energy
# binary_index
# 3                  NaN                         NaN
# 3             1.843231               -1.576441e+49
# 3             1.843231               -1.576441e+49
# 3             1.643431               -1.457503e+49
# 3             1.643431               -1.457503e+49
# 3             1.791892               -8.113320e+48
# 3             0.000174               -4.193196e+46
# 3             0.000000                         NaN
# 3             0.000000                         NaN
# 3             0.000000                         NaN
#
# [10 rows x 40 columns]

# %%
pOneline = pOneline.drop(dropI, axis='index')
pHistory = pHistory.drop(dropI, axis='index')
bhSolRows = bhSolRows.drop(dropI, axis='index')

# %%
print(((pOneline['orbital_period_i'].describe()).to_frame().style.format().to_latex(column_format='|l|r|')).replace('_', '\_').replace('%', '\%'))
# Out:
# \begin{tabular}{|l|r|}
#  & orbital\_period\_i \\
# count & 32.000000 \\
# mean & 4078.269740 \\
# std & 141.930674 \\
# min & 3839.006548 \\
# 25\% & 3980.426902 \\
# 50\% & 4053.498927 \\
# 75\% & 4174.632850 \\
# max & 4356.343911 \\
# \end{tabular}

# %%
print(((pOneline['S2_mass_i'].describe()).to_frame().style.format().to_latex(column_format='|l|r|')).replace('_', '\_').replace('%', '\%'))
# Out:
# \begin{tabular}{|l|r|}
#  & S2\_mass\_i \\
# count & 32.000000 \\
# mean & 2.274376 \\
# std & 0.298457 \\
# min & 1.761954 \\
# 25\% & 2.039521 \\
# 50\% & 2.318450 \\
# 75\% & 2.486227 \\
# max & 2.718105 \\
# \end{tabular}

# %%
print(((pOneline['S1_mass_i'].describe()).to_frame().style.format().to_latex(column_format='|l|r|')).replace('_', '\_').replace('%', '\%'))
# Out:
# \begin{tabular}{|l|r|}
#  & S1\_mass\_i \\
# count & 32.000000 \\
# mean & 17.065503 \\
# std & 1.206662 \\
# min & 15.042657 \\
# 25\% & 16.103260 \\
# 50\% & 17.066792 \\
# 75\% & 17.892084 \\
# max & 19.416319 \\
# \end{tabular}

# %%
pOneline['eccentricity_f'].describe()
# Out:
# count    32.000000
# mean      0.073176
# std       0.234529
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       0.892986
# Name: eccentricity_f, dtype: float64

# %%
graphSave = Path.cwd().parent / 'Reports' /'3_23_26' / 'graphs'

# %%
basicColHist(bhSolRows, 'eccentricity')

# %%
basicColHist(bhSolRows,'S2_mass')

# %%
basicColHist(bhSolRows,'S1_mass', title='BH Masses at Formation in BH-Sol Systems')

# %%
basicColHist(bhSolRows,'orbital_period', saveFig=True, savePath=graphSave)

# %%
slimOP = bhSolRows[bhSolRows['orbital_period'] < 25]['orbital_period']

# %%
genVarHist(slimOP, title='Orbtial Period in Init BH-Sol Systems', xLabel='Orbital Period (days)', saveFig=True, savePath=graphSave)

# %%
# HR_Diagram(bhSolRows,
#            'BhSol',
#            Star_Radius=15)

# %%
xVsY(df = pOneline, xvar= 'S1_mass_i', yvar='S2_mass_i', title='Initial Masses of BH-Sol progenitors', fit=True, saveFig=False, savePath=graphSave)

xVsY(df = bhSolRows, xvar= 'S1_mass', yvar='S2_mass', title='BH-Sol Masses at Initial Formation', fit=True, saveFig=False, savePath=graphSave)

# %%
len(bhSolRows)
# Out:
# 32

# %%
xVsY(useDF=False, xvar=pOneline['S1_mass_i'], yvar=bhSolRows['eccentricity'], fit=True)

# %%
fig, ax = plt.subplots(figsize=(8,5))

var = 'S2_mass_i'
sns.histplot(pOneline[var], bins=50, ax=ax)

title = f'{var} of BH-Sol Systems'

ax.set_title(title)
ax.set_xlabel(var)
ax.set_ylabel('Count')

clean_name = title.replace(' ', '_').replace('/', '-') + '.pgf'
plt.savefig(graphSave / clean_name, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))

var = 'S1_mass_i'
sns.histplot(pOneline[var], bins=50, ax=ax)

title = f'{var} of BH-Sol Systems'

ax.set_title(title)
ax.set_xlabel(var)
ax.set_ylabel('Count')

clean_name = title.replace(' ', '_').replace('/', '-') + '.pgf'
plt.savefig(graphSave / clean_name, bbox_inches='tight')

plt.show()

# %%
SunLike_pop = Population(str(DataPath / 'SunLikeStar_Filt' / 'BH_Sol_Filtered_1e+00_Zsun_population.h5'))
SunLike_bhSolRows = pd.read_csv(DataPath /'SunLikeStar_Filt' / 'BH_Sol_Filtered_1e+00_Zsun_population.csv')

sunlike_pOneline = SunLike_pop.oneline.select()

sunlike_pOneline = sunlike_pOneline.drop(17, axis='index') # failed sim
SunLike_bhSolRows = SunLike_bhSolRows.drop(17, axis='index') # failed sim

# %%
FullPop = Population('/home/bku2126/b1095/bku2126/stellarBHs/grids/g3/1e+00_Zsun_population.h5')

# %%
i = rand.choices(range(1, 1000000), k=1000)

# %%
randSamp = FullPop.oneline[i]

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ci = 95

x1,y1 = pOneline['S1_mass_i'],pOneline['S2_mass_i']
x2,y2 = sunlike_pOneline['S1_mass_i'],sunlike_pOneline['S2_mass_i']
x3,y3 = randSamp['S1_mass_i'],randSamp['S2_mass_i']

sns.regplot(x=x1, y=y1, ci=ci, ax=ax,
            line_kws={"color": "blue", "linestyle": "--", "linewidth": 2, "alpha": .8},
            scatter_kws={"alpha": 0.6}, label="Random Initial Distributions")

sns.regplot(x=x2, y=y2, ci=ci, ax=ax, color= 'red',
            line_kws={"color": "red", "linestyle": "--", "linewidth": 2},
            scatter_kws={"alpha": 0.6}, label="Moe+17 Ps and Qs")


plt.legend(frameon=True)
plt.title('BH-Sol Progenitor ZAMS Masses')

plt.savefig(graphSave / 'MoeDistro_Vs_Rand.pgf', bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5))

ci = 95

x1,y1 = pOneline['S1_mass_i'],pOneline['S2_mass_i']
x2,y2 = sunlike_pOneline['S1_mass_i'],sunlike_pOneline['S2_mass_i']
x3,y3 = randSamp['S1_mass_i'],randSamp['S2_mass_i']

sns.regplot(x=x1, y=y1, ci=ci, ax=ax,
            line_kws={"color": "blue", "linestyle": "--", "linewidth": 2, "alpha": .8},
            scatter_kws={"alpha": 0.6}, label="Random Initial Distributions")

sns.regplot(x=x2, y=y2, ci=ci, ax=ax, color= 'red',
            line_kws={"color": "red", "linestyle": "--", "linewidth": 2},
            scatter_kws={"alpha": 0.6}, label="Moe+17 Ps and Qs")

sns.regplot(x=x3, y=y3, ci=ci, ax=ax, color= 'green',
            line_kws={"color": "green", "linestyle": "--", "linewidth": 2},
            scatter_kws={"alpha": 0.6}, label="Random Sample")

ax.set_xlim(12,25)
ax.set_ylim(0,10)

plt.legend(frameon=True)
plt.title('BH-Sol Progenitors Vs Random Sample')

plt.savefig(graphSave / 'MoeDistro_Vs_Rand_Vs_All.pgf', bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sns.regplot(data = bhSolRows, x='orbital_period', y='eccentricity', ci=ci, ax=ax, color= 'green',
            line_kws={"color": "green", "linestyle": "--", "linewidth": 2},
            scatter_kws={"alpha": 0.6}, label="Random Sample")

plt.show()

# %%
SunLike_bhSolRows['orbital_period']
# Out:
# 0       1.494220
# 1       1.884652
# 2       2.740360
# 3       0.796016
# 4       3.317456
# 5       6.844816
# 6       7.859836
# 7      52.749603
# 8      15.899186
# 9      14.974814
# 10     17.206798
# 11      4.314119
# 12      2.448846
# 13     10.076221
# 14      4.212360
# 15     22.673620
# 16    190.296092
# 18     11.747898
# 19     30.606112
# 20      3.749132
# 21     97.150411
# 22     96.805112
# 23     21.302996
# 24     25.968059
# 25    115.276003
# 26      1.593837
# 27     31.306367
# 28     12.031967
# 29      6.201866
# 30     16.027637
# 31      1.810091
# 32      5.708641
# 33      2.200238
# 34      2.831847
# 35      2.121067
# 36      9.757886
# 37     21.722308
# 38      7.901438
# 39      8.354087
# 40     23.211976
# 41      7.609664
# 42      2.080105
# 43     22.924889
# 44     22.285141
# 45      4.921996
# Name: orbital_period, dtype: float64

# %%
sunlike_pOneline['S1_natal_kick_velocity']
# Out:
# binary_index
# 0     271.903612
# 1      87.409341
# 2     139.253475
# 3     271.048494
# 4     294.292674
# 5     124.883528
# 6     198.952850
# 7     134.536615
# 8      93.175783
# 9     129.996389
# 10    158.616856
# 11    113.741639
# 12    125.783547
# 13    259.298013
# 14    142.553047
# 15     79.661442
# 16    104.683609
# 18    136.267512
# 19    140.376590
# 20    129.199428
# 21     71.664632
# 22    150.824051
# 23    149.591012
# 24    123.288513
# 25    159.105162
# 26    154.194500
# 27    167.240422
# 28    102.996976
# 29    320.149175
# 30     89.161052
# 31    239.560720
# 32    152.467723
# 33    159.596163
# 34    192.369247
# 35    122.147174
# 36     41.397765
# 37    178.890926
# 38    150.264462
# 39     97.300368
# 40    123.638649
# 41    186.173735
# 42    138.669424
# 43    130.694925
# 44     95.168071
# 45    160.805244
# Name: S1_natal_kick_velocity, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sns.regplot( x=SunLike_bhSolRows['orbital_period'], y=sunlike_pOneline['S1_natal_kick_velocity'], ci=ci, ax=ax, color= 'green',
            line_kws={"color": "green", "linestyle": "--", "linewidth": 2},
            scatter_kws={"alpha": 0.6}, label="Random Sample")

plt.show()
