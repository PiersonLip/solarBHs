# %%
# import pandas as pd
from pathlib import Path

# from posydon.popsyn.binarypopulation import BinaryPopulation
# from posydon.binary_evol.binarystar import BinaryStar
# from posydon.binary_evol.singlestar import SingleStar
from posydon.popsyn.synthetic_population import Population
# from posydon.popsyn.synthetic_population import PopulationRunner
# import astropy.units as u

# import os
# import shutil
# from posydon.config import PATH_TO_POSYDON

# from POSYDONHRDiagramModule import HR_Diagram

# import matplotlib.pyplot as plt

# import random as rand

# %%
DataPath = Path().resolve().parent / 'Data'

# %%
pop = Population(str(DataPath / '1e+00_Zsun_population.h5'))

# %%
# bh_solarCond_oneline = "((S1_state_f == 'H-rich_Core_H_burning') & (S2_state_f == 'BH')) | " \
#                "((S2_state_f == 'H-rich_Core_H_burning') & (S1_state_f == 'BH'))"
    
bh_solarCond_history = "(((S1_state == 'H-rich_Core_H_burning') & (S2_state == 'BH')) | " \
                        "((S2_state == 'H-rich_Core_H_burning') & (S1_state == 'BH'))) " \
                        "& (state =='detached')"

# %%
# solBHdf_oneline = pop.oneline.select(where = bh_solarCond_oneline)

solBHdf_history = pop.history.select(where = bh_solarCond_history)

# %%
len(solBHdf_history)
# Out:
# 39208

# %%
pop.history.select(where = solBHdf_history.index.to_list())
# Out:
#                               state      event          time  separation  \
# binary_index
# 6             initially_single_star       ZAMS  7.028220e+09         NaN
# 7             initially_single_star        NaN  1.339237e+10         NaN
# 12                           merged        CC2  8.291354e+09         NaN
# 15                         detached        NaN  4.567700e+08  105.505620
# 15                              ERR     FAILED  5.332784e+08   81.194180
# ...                             ...        ...           ...         ...
# 186703                       merged        END  6.093276e+09         NaN
# 186704                       merged  oMerging2  7.034412e+09  274.882608
# 186717                    disrupted        NaN  8.815547e+09         NaN
# 186719        initially_single_star        END  1.183005e+10         NaN
# 186720                    disrupted        CC2  2.692170e+09         NaN
#
#               orbital_period  eccentricity  rl_relative_overflow_1  \
# binary_index
# 6                        NaN           NaN                     NaN
# 7                        NaN           NaN                     NaN
# 12                       NaN           NaN                     NaN
# 15                 58.671632           0.0                     NaN
# 15                 38.133115           0.0               -1.000000
# ...                      ...           ...                     ...
# 186703                   NaN           NaN                     NaN
# 186704            212.274618           0.0               -0.798684
# 186717                   NaN           NaN                     NaN
# 186719                   NaN           NaN                     NaN
# 186720                   NaN           NaN               -1.000000
#
#               rl_relative_overflow_2  lg_mtransfer_rate      step_names  ...  \
# binary_index                                                             ...
# 6                                NaN                NaN    initial_cond  ...
# 7                                NaN                NaN         step_SN  ...
# 12                               NaN                NaN     step_merged  ...
# 15                               NaN                NaN         step_SN  ...
# 15                         -0.050000                NaN                  ...
# ...                              ...                ...             ...  ...
# 186703                           NaN                NaN        step_end  ...
# 186704                      0.107921          -1.722701         step_CE  ...
# 186717                           NaN                NaN         step_SN  ...
# 186719                           NaN                NaN        step_end  ...
# 186720                     -1.000000                NaN  step_disrupted  ...
#
#               S2_conv_env_turnover_time_l_b  S2_conv_env_turnover_time_l_t  \
# binary_index
# 6                                       NaN                            NaN
# 7                                       NaN                            NaN
# 12                             2.556706e-02                   7.579491e+05
# 15                             0.000000e+00                   0.000000e+00
# 15                             5.063788e-01                   1.397576e+07
# ...                                     ...                            ...
# 186703                                  NaN                            NaN
# 186704                         1.221546e+07                   1.025149e+07
# 186717                                  NaN                            NaN
# 186719                                  NaN                            NaN
# 186720                         1.128190e-02                   3.554186e+05
#
#               S2_envelope_binding_energy  S2_mass_conv_reg_fortides  \
# binary_index
# 6                                    NaN                        NaN
# 7                                    NaN                        NaN
# 12                         -6.646511e+46               4.605988e+00
# 15                         -1.873827e+49               2.217637e-08
# 15                         -2.747111e+48               2.395667e+00
# ...                                  ...                        ...
# 186703                               NaN                        NaN
# 186704                     -7.229906e+48               1.283760e+00
# 186717                               NaN                        NaN
# 186719                               NaN                        NaN
# 186720                     -1.448728e+48               5.832895e-02
#
#              S2_thickness_conv_reg_fortides  S2_radius_conv_reg_fortides  \
# binary_index
# 6                                       NaN                          NaN
# 7                                       NaN                          NaN
# 12                               531.742358                   272.063379
# 15                                 0.037616                     3.349910
# 15                                28.867452                    25.403073
# ...                                     ...                          ...
# 186703                                  NaN                          NaN
# 186704                            76.401155                    77.185059
# 186717                                  NaN                          NaN
# 186719                                  NaN                          NaN
# 186720                             0.000702                     0.013014
#
#               S2_lambda_CE_1cent  S2_lambda_CE_10cent  S2_lambda_CE_30cent  \
# binary_index
# 6                            NaN                  NaN                  NaN
# 7                            NaN                  NaN                  NaN
# 12                      1.107421             1.192890             1.194732
# 15                      0.808419             0.808419             0.808419
# 15                      0.485822             0.583973             1.093616
# ...                          ...                  ...                  ...
# 186703                       NaN                  NaN                  NaN
# 186704                  0.118552             0.126290             0.138658
# 186717                       NaN                  NaN                  NaN
# 186719                       NaN                  NaN                  NaN
# 186720                  0.102897             0.148572             0.328442
#
#               S2_lambda_CE_pure_He_star_10cent
# binary_index
# 6                                          NaN
# 7                                          NaN
# 12                                    0.002989
# 15                                    0.808463
# 15                                    0.208025
# ...                                        ...
# 186703                                     NaN
# 186704                                0.039799
# 186717                                     NaN
# 186719                                     NaN
# 186720                                0.001137
#
# [39208 rows x 120 columns]

# %%
pop.export_selection(solBHdf_history.index.to_list(), (DataPath / 'bhSolSubpop.h5'), append=False)
